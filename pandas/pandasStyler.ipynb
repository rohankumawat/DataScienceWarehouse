# %%
import pandas as pd
df = pd.read_csv("spotify2021_1000.csv")
df.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                         artist_name                  track_name  \
# 0        Carolina Gaitán - La Gaita   We Don't Talk About Bruno
# 1                             LYMEY            END OF YEAR 2021
# 2                          Coldplay                 My Universe
# 3  Elvis Costello & The Attractions  Pump It Up - 2021 Remaster
# 4                       Kodak Black               Super Gremlin
#
#                  track_id  popularity  danceability  energy  key  loudness  \
# 0  52xJxFP6TqMuO4Yt0eOkMz          95         0.577   0.450    0    -8.516
# 1  6usFCFN0F69JcAaHtB55sg          28         0.429   0.829    6    -5.071
# 2  3FeVmId7tL5YN8B7R3imoM          92         0.588   0.701    9    -6.390
# 3  3oyc1mIdCBGaU55wX7otqM          67         0.645   0.809   11    -6.120
# 4  4A8cWXxKfIL3lAyUDzXbCF          91         0.825   0.414    2    -6.634
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
df.tail()
# Out:
#      artist_name                  track_name                track_id  \
# 959    Tom Staar      Playing Games (RES006)  1snj0k1q66wzENWRrhpGuZ
# 960  THE ANXIETY  Meet Me At Our Spot - Live  3BrWLBC4WYx393yRUOlTih
# 961        Felon         Fine Lines (RES006)  4btHQMcikOKuEq1FgvtQ2D
# 962      ENHYPEN                       FEVER  0UzymivvUH5s8z4PeWZJaK
# 963    Dim3nsion    Before The Rain (RES006)  7vWsP0DleQ2eQS5HZJyOn6
#
#      popularity  danceability  energy  key  loudness  mode  speechiness  \
# 959          17         0.384   0.868    2    -8.551     1       0.0517
# 960          77         0.694   0.475    2    -7.035     1       0.0345
# 961          15         0.622   0.899    8    -5.273     0       0.0494
# 962          83         0.600   0.713    6    -5.079     0       0.0592
# 963          16         0.615   0.908    1    -9.475     0       0.0319
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
# highligt maximum values
df.style.highlight_max()
# Out:
# <style type="text/css">
# ...

# %%
# highlight minimum values
df.style.highlight_min()
# Out:
# <style type="text/css">
# ...
